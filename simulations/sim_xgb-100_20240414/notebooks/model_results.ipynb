# %% [markdown]
# # Model Results

# %% [markdown]
# <script>
#     document.querySelector('head').innerHTML += '<style>.slides { zoom: 0.975 !important; }</style>';
# </script>
# <style>
# /* Ensure the entire cell and its output take full width */
# .reveal .slides > section .cell {
#     width: 90% !important;
#     margin: 0 auto;
# }
#
# .reveal .slides > section .output {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
#     margin: 0 auto;
# }
#
# /* Optional: Adjust the slide width if necessary */
# .reveal .slides {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
# }
#
#
# </style>

# %%
config_file = "../config_sim_xgb-100_20240414.ini"

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import boxplot_model_results

# %%
config = ConfigParser()
config.read(config_file)
# Out:
# ['../config_sim_xgb-100_20240414.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#     index                           model_id         model  simulation  \
# 0       0   XGBRegressor_20240414_1_1000_0.1  XGBRegressor           1
# 1       0   XGBRegressor_20240414_1_1000_0.5  XGBRegressor           1
# 2       0   XGBRegressor_20240414_2_1000_0.1  XGBRegressor           2
# 3       0   XGBRegressor_20240414_2_1000_0.5  XGBRegressor           2
# 4       0   XGBRegressor_20240414_3_1000_0.1  XGBRegressor           3
# ..    ...                                ...           ...         ...
# 59      0  XGBRegressor_20240415_30_1000_0.5  XGBRegressor          30
# 60      0  XGBRegressor_20240415_31_1000_0.1  XGBRegressor          31
# 61      0  XGBRegressor_20240415_31_1000_0.5  XGBRegressor          31
# 62      0  XGBRegressor_20240415_32_1000_0.1  XGBRegressor          32
# 63      0  XGBRegressor_20240415_32_1000_0.5  XGBRegressor          32
#
#     n_train  noise_sd  mse_train  mse_test  mae_train  mae_test  r2_train  \
# 0      1000       0.1   0.000746  0.293658   0.019431  0.406508  0.999970
# 1      1000       0.5   0.017015  0.589488   0.100901  0.600300  0.999322
# 2      1000       0.1   0.000968  0.328785   0.023671  0.416093  0.999958
# 3      1000       0.5   0.027323  0.604914   0.127741  0.597023  0.998810
# 4      1000       0.1   0.002674  0.261840   0.039827  0.369762  0.999882
# ..      ...       ...        ...       ...        ...       ...       ...
# 59     1000       0.5   0.039451  0.636099   0.155005  0.633804  0.998357
# 60     1000       0.1   0.003766  0.302183   0.046567  0.421970  0.999842
# 61     1000       0.5   0.042944  0.573675   0.160634  0.603000  0.998223
# 62     1000       0.1   0.009248  0.330071   0.073545  0.424177  0.999606
# 63     1000       0.5   0.020314  0.626925   0.109867  0.629956  0.999139
#
#      r2_test
# 0   0.988059
# 1   0.976369
# 2   0.985578
# 3   0.973947
# 4   0.989269
# ..       ...
# 59  0.974763
# 60  0.987670
# 61  0.976772
# 62  0.986219
# 63  0.974265
#
# [64 rows x 12 columns]

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
