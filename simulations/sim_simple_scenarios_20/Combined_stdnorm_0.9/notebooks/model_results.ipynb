# %% [markdown]
# # Model Results

# %% [markdown]
# <script>
#     document.querySelector('head').innerHTML += '<style>.slides { zoom: 0.975 !important; }</style>';
# </script>
# <style>
# /* Ensure the entire cell and its output take full width */
# .reveal .slides > section .cell {
#     width: 90% !important;
#     margin: 0 auto;
# }
#
# .reveal .slides > section .output {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
#     margin: 0 auto;
# }
#
# /* Optional: Adjust the slide width if necessary */
# .reveal .slides {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
# }
#
#
# </style>

# %%
config_file = "../../config_sim_simple_scenarios_20.ini"

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import boxplot_model_results

# %%
config = ConfigParser()
config.read(config_file)
# Out:
# ['../../config_sim_simple_scenarios_20.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#      index                     model_id              model  simulation  \
# 0        0  XGBoost-2comb-cor_1_1000_10  XGBoost-2comb-cor           1
# 1        0       XGBoost-full_1_1000_10       XGBoost-full           1
# 2        0            SVM-RBF_1_1000_10            SVM-RBF           1
# 3        0      GAM-2comb-cor_1_1000_10      GAM-2comb-cor           1
# 4        0         GAM-4-full_1_1000_10         GAM-4-full           1
# ..     ...                          ...                ...         ...
# 134      0        GAM-4-full_14_1000_10         GAM-4-full          14
# 135      0  XGBoost-2comb-cor_14_1000_5  XGBoost-2comb-cor          14
# 136      0       XGBoost-full_14_1000_5       XGBoost-full          14
# 137      0            SVM-RBF_14_1000_5            SVM-RBF          14
# 138      0      GAM-2comb-cor_14_1000_5      GAM-2comb-cor          14
#
#      n_train   snr  mse_train  mse_test  mae_train  mae_test  r2_train  \
# 0       1000  10.0   0.079481  0.179353   0.114556  0.249165  0.986319
# 1       1000  10.0   0.017879  0.182280   0.099350  0.266170  0.996923
# 2       1000  10.0   0.048364  0.054282   0.174470  0.185616  0.991675
# 3       1000  10.0   0.048879  0.052544   0.175903  0.183005  0.991587
# 4       1000  10.0   0.044333  0.056250   0.167913  0.189171  0.992369
# ..       ...   ...        ...       ...        ...       ...       ...
# 134     1000  10.0   0.047173  0.056613   0.172484  0.189262  0.990082
# 135     1000   5.0   0.172064  0.303393   0.314720  0.411185  0.964949
# 136     1000   5.0   0.165413  0.298214   0.294319  0.407646  0.966304
# 137     1000   5.0   0.211012  0.216546   0.362383  0.371152  0.957015
# 138     1000   5.0   0.202972  0.217252   0.358331  0.371586  0.958653
#
#       r2_test
# 0    0.965759
# 1    0.965200
# 2    0.989637
# 3    0.989969
# 4    0.989261
# ..        ...
# 134  0.988570
# 135  0.940496
# 136  0.941512
# 137  0.957529
# 138  0.957391
#
# [139 rows x 12 columns]

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
