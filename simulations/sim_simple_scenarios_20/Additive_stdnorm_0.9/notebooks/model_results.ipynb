# %% [markdown]
# # Model Results

# %% [markdown]
# <script>
#     document.querySelector('head').innerHTML += '<style>.slides { zoom: 0.975 !important; }</style>';
# </script>
# <style>
# /* Ensure the entire cell and its output take full width */
# .reveal .slides > section .cell {
#     width: 90% !important;
#     margin: 0 auto;
# }
#
# .reveal .slides > section .output {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
#     margin: 0 auto;
# }
#
# /* Optional: Adjust the slide width if necessary */
# .reveal .slides {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
# }
#
#
# </style>

# %%
config_file = "../../config_sim_simple_scenarios_20.ini"

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import boxplot_model_results

# %%
config = ConfigParser()
config.read(config_file)
# Out:
# ['../../config_sim_simple_scenarios_20.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#      index                    model_id             model  simulation  n_train  \
# 0        0  XGBoost-2add-cor_1_1000_10  XGBoost-2add-cor           1     1000
# 1        0      XGBoost-full_1_1000_10      XGBoost-full           1     1000
# 2        0           SVM-RBF_1_1000_10           SVM-RBF           1     1000
# 3        0      GAM-2add-cor_1_1000_10      GAM-2add-cor           1     1000
# 4        0        GAM-4-full_1_1000_10        GAM-4-full           1     1000
# ..     ...                         ...               ...         ...      ...
# 152      0          SVM-RBF_16_1000_10           SVM-RBF          16     1000
# 153      0     GAM-2add-cor_16_1000_10      GAM-2add-cor          16     1000
# 154      0       GAM-4-full_16_1000_10        GAM-4-full          16     1000
# 155      0  XGBoost-2add-cor_16_1000_5  XGBoost-2add-cor          16     1000
# 156      0      XGBoost-full_16_1000_5      XGBoost-full          16     1000
#
#       snr  mse_train  mse_test  mae_train  mae_test  r2_train   r2_test
# 0    10.0   0.026337  0.032812   0.104704  0.128978  0.983756  0.978263
# 1    10.0   0.018721  0.033992   0.074270  0.129277  0.988453  0.977481
# 2    10.0   0.014808  0.016236   0.097228  0.101817  0.990867  0.989244
# 3    10.0   0.014778  0.015819   0.096665  0.100422  0.990885  0.989520
# 4    10.0   0.013298  0.017009   0.091930  0.103994  0.991798  0.988732
# ..    ...        ...       ...        ...       ...       ...       ...
# 152  10.0   0.015073  0.016084   0.097931  0.101010  0.989815  0.989339
# 153  10.0   0.014286  0.015760   0.094990  0.099870  0.990348  0.989553
# 154  10.0   0.013177  0.016603   0.091816  0.102460  0.991096  0.988994
# 155   5.0   0.074248  0.098796   0.187558  0.227754  0.951131  0.936569
# 156   5.0   0.051130  0.094582   0.157832  0.225770  0.966347  0.939275
#
# [157 rows x 12 columns]

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
