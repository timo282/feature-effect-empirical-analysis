# %% [markdown]
# # Model Results

# %% [markdown]
# <script>
#     document.querySelector('head').innerHTML += '<style>.slides { zoom: 0.975 !important; }</style>';
# </script>
# <style>
# /* Ensure the entire cell and its output take full width */
# .reveal .slides > section .cell {
#     width: 90% !important;
#     margin: 0 auto;
# }
#
# .reveal .slides > section .output {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
#     margin: 0 auto;
# }
#
# /* Optional: Adjust the slide width if necessary */
# .reveal .slides {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
# }
#
#
# </style>

# %%
config_file = "../../config_sim_simple_scenarios_20.ini"

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import boxplot_model_results

# %%
config = ConfigParser()
config.read(config_file)
# Out:
# ['../../config_sim_simple_scenarios_20.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#      index                    model_id             model  simulation  n_train  \
# 0        0  XGBoost-2add-cor_1_1000_10  XGBoost-2add-cor           1     1000
# 1        0      XGBoost-full_1_1000_10      XGBoost-full           1     1000
# 2        0           SVM-RBF_1_1000_10           SVM-RBF           1     1000
# 3        0      GAM-2add-cor_1_1000_10      GAM-2add-cor           1     1000
# 4        0        GAM-4-full_1_1000_10        GAM-4-full           1     1000
# ..     ...                         ...               ...         ...      ...
# 195      0  XGBoost-2add-cor_20_1000_5  XGBoost-2add-cor          20     1000
# 196      0      XGBoost-full_20_1000_5      XGBoost-full          20     1000
# 197      0           SVM-RBF_20_1000_5           SVM-RBF          20     1000
# 198      0      GAM-2add-cor_20_1000_5      GAM-2add-cor          20     1000
# 199      0        GAM-4-full_20_1000_5        GAM-4-full          20     1000
#
#       snr  mse_train  mse_test  mae_train  mae_test  r2_train   r2_test
# 0    10.0   0.016685  0.034919   0.091095  0.133479  0.989853  0.976780
# 1    10.0   0.005567  0.036209   0.058693  0.133297  0.996615  0.975922
# 2    10.0   0.014414  0.015406   0.096147  0.099338  0.991234  0.989755
# 3    10.0   0.014211  0.015390   0.094785  0.099012  0.991358  0.989766
# 4    10.0   0.012737  0.016501   0.089752  0.102518  0.992254  0.989028
# ..    ...        ...       ...        ...       ...       ...       ...
# 195   5.0   0.043508  0.089133   0.164365  0.223773  0.971071  0.944363
# 196   5.0   0.030695  0.100261   0.136575  0.229859  0.979591  0.937417
# 197   5.0   0.053992  0.063326   0.184466  0.200367  0.964100  0.960472
# 198   5.0   0.053176  0.062075   0.183988  0.198093  0.964642  0.961253
# 199   5.0   0.048211  0.065137   0.175213  0.203414  0.967944  0.959342
#
# [200 rows x 12 columns]

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
