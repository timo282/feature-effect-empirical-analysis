# %% [markdown]
# # Model Results

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import (
    boxplot_model_results,
)

# %%
config = ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#    index                                   model_id                  model  \
# 0      0  RandomForestRegressor_20240404_1_1000_0.1  RandomForestRegressor
# 1      0  RandomForestRegressor_20240405_1_1000_0.5  RandomForestRegressor
# 2      0  RandomForestRegressor_20240405_2_1000_0.1  RandomForestRegressor
# 3      0  RandomForestRegressor_20240405_2_1000_0.5  RandomForestRegressor
# 4      0  RandomForestRegressor_20240405_3_1000_0.1  RandomForestRegressor
# 5      0  RandomForestRegressor_20240405_3_1000_0.5  RandomForestRegressor
# 6      0  RandomForestRegressor_20240405_4_1000_0.1  RandomForestRegressor
# 7      0  RandomForestRegressor_20240405_4_1000_0.5  RandomForestRegressor
# 8      0  RandomForestRegressor_20240405_5_1000_0.1  RandomForestRegressor
# 9      0  RandomForestRegressor_20240405_5_1000_0.5  RandomForestRegressor
#
#    simulation  n_train  noise_sd  mse_train  mse_test  mae_train  mae_test  \
# 0           1     1000       0.1   1.045456  2.576617   0.800125  1.264086
# 1           1     1000       0.5   1.162198  2.890253   0.844233  1.337298
# 2           2     1000       0.1   0.997681  2.531358   0.786782  1.255239
# 3           2     1000       0.5   1.115552  2.859424   0.839635  1.330010
# 4           3     1000       0.1   0.957492  2.743646   0.773363  1.312219
# 5           3     1000       0.5   1.049854  2.993291   0.814242  1.356523
# 6           4     1000       0.1   1.028198  2.870356   0.791520  1.346798
# 7           4     1000       0.5   1.114105  3.199119   0.821091  1.417973
# 8           5     1000       0.1   1.116805  2.830539   0.831025  1.317689
# 9           5     1000       0.5   1.188113  3.022323   0.857038  1.359524
#
#    r2_train   r2_test
# 0  0.957896  0.895225
# 1  0.953693  0.884136
# 2  0.956467  0.888965
# 3  0.951427  0.876846
# 4  0.957644  0.887553
# 5  0.953961  0.877753
# 6  0.952931  0.883610
# 7  0.949115  0.871911
# 8  0.952417  0.886576
# 9  0.950161  0.880592

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
