# %% [markdown]
# # Model Results

# %% [markdown]
# <script>
#     document.querySelector('head').innerHTML += '<style>.slides { zoom: 0.975 !important; }</style>';
# </script>
# <style>
# /* Ensure the entire cell and its output take full width */
# .reveal .slides > section .cell {
#     width: 90% !important;
#     margin: 0 auto;
# }
#
# .reveal .slides > section .output {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
#     margin: 0 auto;
# }
#
# /* Optional: Adjust the slide width if necessary */
# .reveal .slides {
#     width: 90% !important;
#     max-width: 90% !important;
#     height: 90% !important;
#     max-height: 90% !important;
# }
#
#
# </style>

# %%
from configparser import ConfigParser
import pandas as pd

from feature_effect_empirical_analysis.plotting.plots import (
    boxplot_model_results,
)

# %%
config = ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %%
model_results_storage = config.get("storage", "model_results")
df = pd.read_sql_table("model_results", f"sqlite:///..{model_results_storage}")
df
# Out:
#     index                                   model_id                  model  \
# 0       0  RandomForestRegressor_20240407_1_1000_0.1  RandomForestRegressor
# 1       0           XGBRegressor_20240407_1_1000_0.1           XGBRegressor
# 2       0  DecisionTreeRegressor_20240407_1_1000_0.1  DecisionTreeRegressor
# 3       0                    SVR_20240407_1_1000_0.1                    SVR
# 4       0             ElasticNet_20240407_1_1000_0.1             ElasticNet
# 5       0  RandomForestRegressor_20240407_1_1000_0.5  RandomForestRegressor
# 6       0           XGBRegressor_20240407_1_1000_0.5           XGBRegressor
# 7       0  DecisionTreeRegressor_20240407_1_1000_0.5  DecisionTreeRegressor
# 8       0                    SVR_20240407_1_1000_0.5                    SVR
# 9       0             ElasticNet_20240407_1_1000_0.5             ElasticNet
# 10      0  RandomForestRegressor_20240407_2_1000_0.1  RandomForestRegressor
# 11      0           XGBRegressor_20240407_2_1000_0.1           XGBRegressor
# 12      0  DecisionTreeRegressor_20240407_2_1000_0.1  DecisionTreeRegressor
# 13      0                    SVR_20240407_2_1000_0.1                    SVR
# 14      0             ElasticNet_20240408_2_1000_0.1             ElasticNet
# 15      0  RandomForestRegressor_20240408_2_1000_0.5  RandomForestRegressor
# 16      0           XGBRegressor_20240408_2_1000_0.5           XGBRegressor
# 17      0  DecisionTreeRegressor_20240408_2_1000_0.5  DecisionTreeRegressor
# 18      0                    SVR_20240408_2_1000_0.5                    SVR
# 19      0             ElasticNet_20240408_2_1000_0.5             ElasticNet
# 20      0  RandomForestRegressor_20240408_3_1000_0.1  RandomForestRegressor
# 21      0           XGBRegressor_20240408_3_1000_0.1           XGBRegressor
# 22      0  DecisionTreeRegressor_20240408_3_1000_0.1  DecisionTreeRegressor
# 23      0                    SVR_20240408_3_1000_0.1                    SVR
# 24      0             ElasticNet_20240408_3_1000_0.1             ElasticNet
# 25      0  RandomForestRegressor_20240408_3_1000_0.5  RandomForestRegressor
# 26      0           XGBRegressor_20240408_3_1000_0.5           XGBRegressor
# 27      0  DecisionTreeRegressor_20240408_3_1000_0.5  DecisionTreeRegressor
# 28      0                    SVR_20240408_3_1000_0.5                    SVR
# 29      0             ElasticNet_20240408_3_1000_0.5             ElasticNet
# 30      0  RandomForestRegressor_20240408_4_1000_0.1  RandomForestRegressor
# 31      0           XGBRegressor_20240408_4_1000_0.1           XGBRegressor
# 32      0  DecisionTreeRegressor_20240408_4_1000_0.1  DecisionTreeRegressor
# 33      0                    SVR_20240408_4_1000_0.1                    SVR
# 34      0             ElasticNet_20240408_4_1000_0.1             ElasticNet
# 35      0  RandomForestRegressor_20240408_4_1000_0.5  RandomForestRegressor
# 36      0           XGBRegressor_20240408_4_1000_0.5           XGBRegressor
# 37      0  DecisionTreeRegressor_20240408_4_1000_0.5  DecisionTreeRegressor
# 38      0                    SVR_20240408_4_1000_0.5                    SVR
# 39      0             ElasticNet_20240408_4_1000_0.5             ElasticNet
# 40      0  RandomForestRegressor_20240408_5_1000_0.1  RandomForestRegressor
# 41      0           XGBRegressor_20240408_5_1000_0.1           XGBRegressor
# 42      0  DecisionTreeRegressor_20240408_5_1000_0.1  DecisionTreeRegressor
# 43      0                    SVR_20240408_5_1000_0.1                    SVR
# 44      0             ElasticNet_20240408_5_1000_0.1             ElasticNet
# 45      0  RandomForestRegressor_20240408_5_1000_0.5  RandomForestRegressor
# 46      0           XGBRegressor_20240408_5_1000_0.5           XGBRegressor
# 47      0  DecisionTreeRegressor_20240408_5_1000_0.5  DecisionTreeRegressor
# 48      0                    SVR_20240408_5_1000_0.5                    SVR
# 49      0             ElasticNet_20240408_5_1000_0.5             ElasticNet
#
#     simulation  n_train  noise_sd  mse_train  mse_test  mae_train  mae_test  \
# 0            1     1000       0.1   1.061477  2.579855   0.806841  1.267990
# 1            1     1000       0.1   0.003230  0.276231   0.042042  0.387710
# 2            1     1000       0.1   1.592632  5.658174   0.985326  1.879092
# 3            1     1000       0.1   0.009583  0.018337   0.081111  0.103061
# 4            1     1000       0.1   5.716357  6.326010   1.822135  1.928950
# 5            1     1000       0.5   1.164493  2.879359   0.844467  1.334659
# 6            1     1000       0.5   0.021815  0.617743   0.114820  0.617056
# 7            1     1000       0.5   1.291587  5.835857   0.864694  1.899462
# 8            1     1000       0.5   0.217337  0.292701   0.353357  0.434191
# 9            1     1000       0.5   6.001154  6.663442   1.875517  1.974429
# 10           2     1000       0.1   1.000421  2.520993   0.789242  1.251487
# 11           2     1000       0.1   0.005213  0.305134   0.054853  0.405413
# 12           2     1000       0.1   1.199006  4.655333   0.846119  1.712575
# 13           2     1000       0.1   0.009388  0.015729   0.080623  0.097832
# 14           2     1000       0.1   5.729670  5.603475   1.818703  1.835518
# 15           2     1000       0.5   1.138042  2.863569   0.846051  1.331973
# 16           2     1000       0.5   0.025332  0.621259   0.122430  0.607071
# 17           2     1000       0.5   2.059944  5.130850   1.108003  1.782196
# 18           2     1000       0.5   0.218487  0.303596   0.352180  0.435328
# 19           2     1000       0.5   5.951501  5.899967   1.863729  1.878424
# 20           3     1000       0.1   0.933716  2.789704   0.762083  1.320636
# 21           3     1000       0.1   0.000727  0.273116   0.020456  0.384366
# 22           3     1000       0.1   1.574273  5.567450   0.982717  1.861938
# 23           3     1000       0.1   0.010235  0.016686   0.083425  0.098279
# 24           3     1000       0.1   5.574418  6.058893   1.836146  1.937617
# 25           3     1000       0.5   1.160047  3.053715   0.859082  1.373789
# 26           3     1000       0.5   0.040225  0.581994   0.153780  0.586387
# 27           3     1000       0.5   1.602286  5.873162   0.987382  1.910930
# 28           3     1000       0.5   0.234813  0.292969   0.365463  0.431633
# 29           3     1000       0.5   5.755439  6.248423   1.861620  1.969459
# 30           4     1000       0.1   1.026697  2.859830   0.790563  1.344493
# 31           4     1000       0.1   0.000464  0.342191   0.016221  0.448222
# 32           4     1000       0.1   1.320336  5.072667   0.852916  1.791384
# 33           4     1000       0.1   0.008918  0.017733   0.078619  0.104719
# 34           4     1000       0.1   5.850776  6.116062   1.843441  1.925554
# 35           4     1000       0.5   1.071110  3.247963   0.805296  1.424363
# 36           4     1000       0.5   0.001934  0.708289   0.032797  0.664304
# 37           4     1000       0.5   1.307334  5.726058   0.859618  1.913856
# 38           4     1000       0.5   0.217935  0.315307   0.353145  0.445518
# 39           4     1000       0.5   6.056966  6.462666   1.886121  1.988363
# 40           5     1000       0.1   1.114586  2.827651   0.830868  1.313985
# 41           5     1000       0.1   0.003731  0.313863   0.047462  0.423029
# 42           5     1000       0.1   1.810721  5.400536   1.041824  1.820424
# 43           5     1000       0.1   0.009398  0.016618   0.079992  0.102861
# 44           5     1000       0.1   5.728094  6.305702   1.851232  1.990773
# 45           5     1000       0.5   1.220371  3.039326   0.867942  1.363277
# 46           5     1000       0.5   0.020554  0.600762   0.110879  0.616600
# 47           5     1000       0.5   1.465710  5.821884   0.937452  1.898664
# 48           5     1000       0.5   0.229592  0.318557   0.358809  0.454377
# 49           5     1000       0.5   6.028776  6.550014   1.905341  2.026058
#
#     r2_train   r2_test
# 0   0.957251  0.895093
# 1   0.999870  0.988767
# 2   0.935860  0.769917
# 3   0.999614  0.999254
# 4   0.769785  0.742760
# 5   0.953601  0.884573
# 6   0.999131  0.975236
# 7   0.948537  0.766054
# 8   0.991340  0.988266
# 9   0.760886  0.732878
# 10  0.956347  0.889419
# 11  0.999773  0.986616
# 12  0.947682  0.795799
# 13  0.999590  0.999310
# 14  0.749988  0.754210
# 15  0.950448  0.876667
# 16  0.998897  0.973243
# 17  0.910307  0.779017
# 18  0.990487  0.986924
# 19  0.740863  0.745891
# 20  0.958696  0.885666
# 21  0.999968  0.988807
# 22  0.930360  0.771821
# 23  0.999547  0.999316
# 24  0.753410  0.751680
# 25  0.949128  0.875285
# 26  0.998236  0.976231
# 27  0.929735  0.760138
# 28  0.989703  0.988035
# 29  0.747606  0.744813
# 30  0.953000  0.884037
# 31  0.999979  0.986124
# 32  0.939557  0.794309
# 33  0.999592  0.999281
# 34  0.732162  0.752000
# 35  0.951078  0.869955
# 36  0.999912  0.971641
# 37  0.940289  0.770736
# 38  0.990046  0.987375
# 39  0.723355  0.741243
# 40  0.952512  0.886692
# 41  0.999841  0.987423
# 42  0.922852  0.783593
# 43  0.999600  0.999334
# 44  0.755947  0.747321
# 45  0.948808  0.879920
# 46  0.999138  0.976265
# 47  0.938516  0.769985
# 48  0.990369  0.987414
# 49  0.747104  0.741217

# %%
# %matplotlib inline
boxplot_model_results(metric='mse', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='mae', df=df);

# %%
# %matplotlib inline
boxplot_model_results(metric='r2', df=df);
