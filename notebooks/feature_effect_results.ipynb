# %%
from configparser import ConfigParser
import pandas as pd

# %%
config = ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %%
pdp_results_storage = config.get("storage", "pdp_results")
df = pd.read_sql_table("pdp_results", f"sqlite:///..{pdp_results_storage}")
df
# Out:
#    index                                   model_id                  model  \
# 0      0  RandomForestRegressor_20240406_1_1000_0.1  RandomForestRegressor
# 1      0  RandomForestRegressor_20240406_1_1000_0.5  RandomForestRegressor
# 2      0  RandomForestRegressor_20240406_2_1000_0.1  RandomForestRegressor
# 3      0  RandomForestRegressor_20240406_2_1000_0.5  RandomForestRegressor
# 4      0  RandomForestRegressor_20240406_3_1000_0.1  RandomForestRegressor
# 5      0  RandomForestRegressor_20240406_3_1000_0.5  RandomForestRegressor
# 6      0  RandomForestRegressor_20240406_4_1000_0.1  RandomForestRegressor
# 7      0  RandomForestRegressor_20240406_4_1000_0.5  RandomForestRegressor
# 8      0  RandomForestRegressor_20240406_5_1000_0.1  RandomForestRegressor
# 9      0  RandomForestRegressor_20240406_5_1000_0.5  RandomForestRegressor
#
#    simulation  n_train  noise_sd       x_1       x_2       x_3       x_4  \
# 0           1     1000       0.1  3.038481  3.245868  1.890912  5.566741
# 1           1     1000       0.5  3.050328  3.233369  1.890139  5.553690
# 2           2     1000       0.1  3.088404  3.195086  1.834036  5.569074
# 3           2     1000       0.5  3.066303  3.203459  1.836846  5.618116
# 4           3     1000       0.1  3.002459  3.149936  1.900715  5.550629
# 5           3     1000       0.5  3.003687  3.140356  1.901121  5.571770
# 6           4     1000       0.1  3.256450  3.174999  1.927848  5.734279
# 7           4     1000       0.5  3.267522  3.189437  1.935134  5.724541
# 8           5     1000       0.1  3.130598  2.890491  1.894103  5.534949
# 9           5     1000       0.5  3.133027  2.884964  1.885066  5.526730
#
#         x_5
# 0  1.290257
# 1  1.285426
# 2  1.323738
# 3  1.324014
# 4  1.352888
# 5  1.344186
# 6  1.322454
# 7  1.320076
# 8  1.392000
# 9  1.383268
